# %%
import pandas as pd

# Load the data
file_path = 'combined_product_data (1).csv'
data = pd.read_csv(file_path)

# Check for NaN values in 'periodname'
missing_periodname = data['periodname'].isna().sum()
print(f'Missing values in periodname: {missing_periodname}')

# Drop rows with NaN values in 'periodname'
data = data.dropna(subset=['periodname'])

# Convert 'periodname' to datetime using the correct format
try:
    data['periodname'] = pd.to_datetime(data['periodname'], format='%B %Y')
except ValueError as e:
    print(f"Error in date conversion: {e}")

# Display the first few rows to verify
print(data.head())
# Out:
# The kernel failed to start due to the missing module 'packaging'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
# import pandas as pd
# from prophet import Prophet

# # Load the data
# file_path = 'combined_product_data (1).csv'
# data = pd.read_csv(file_path)

# # Function to parse dates with multiple formats
# def parse_dates(date_str):
#     for fmt in ('%B %Y', '%b-%y'):
#         try:
#             return pd.to_datetime(date_str, format=fmt)
#         except ValueError:
#             continue
#     return pd.NaT  # Return NaT if no format matches

# # Apply the function to the 'periodname' column
# data['periodname'] = data['periodname'].apply(parse_dates)

# # Drop rows with unprocessable date values
# data = data.dropna(subset=['periodname'])

# # Filter out any dates that are out of bounds for the Prophet model
# data = data[(data['periodname'] >= '1900-01-01') & (data['periodname'] <= '2100-12-31')]

# # Prepare the data for Prophet
# # Prophet requires columns 'ds' and 'y' for the date and value respectively
# data_prophet = data[['periodname', 'value']].rename(columns={'periodname': 'ds', 'value': 'y'})

# # Initialize and train the model
# model = Prophet()
# model.fit(data_prophet)

# # Make a future dataframe for predictions
# future = model.make_future_dataframe(periods=12, freq='M')  # Forecast for the next 12 months
# forecast = model.predict(future)

# # Plot the forecast
# fig = model.plot(forecast)
# fig.show()
# import streamlit as st
# import pandas as pd
# from prophet import Prophet
# from prophet.plot import plot_plotly

# # Load the data
# data = pd.read_csv('combined_product_data (1).csv')

# # Drop rows with NaN values in 'periodname'
# data = data.dropna(subset=['periodname'])

# # Convert 'periodname' to datetime
# data['periodname'] = data['periodname'].apply(parse_dates)

# # Drop rows with unprocessable date values
# data = data.dropna(subset=['periodname'])

# # Streamlit UI
# st.title('Time Series Forecasting with Prophet')

# # Select organization unit and common name for forecasting
# org_unit = st.selectbox('Select Organization Unit', data['organisationunitname'].unique())
# common_name = st.selectbox('Select Common Name', data['common_name'].unique())

# # Filter data based on selections
# filtered_data = data[(data['organisationunitname'] == org_unit) & (data['common_name'] == common_name)]

# # Prepare the data for Prophet
# data_prophet = filtered_data[['periodname', 'value']].rename(columns={'periodname': 'ds', 'value': 'y'})

# # Initialize and train the model
# model = Prophet()
# model.fit(data_prophet)

# # Make a future dataframe for predictions
# future = model.make_future_dataframe(periods=12, freq='M')  # Forecast for the next 12 months
# forecast = model.predict(future)

# # Plot the forecast
# fig = plot_plotly(model, forecast)  # This returns a plotly Figure

# # Show the plot in Streamlit
# st.plotly_chart(fig)

# # Display forecast data
# st.write(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
# Out:
# The kernel failed to start due to the missing module 'packaging'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
# import streamlit as st
# import pandas as pd
# from prophet import Prophet
# from prophet.plot import plot_plotly
# import plotly.graph_objs as go

# # Load the data
# data = pd.read_csv('combined_product_data (1).csv')

# # Drop rows with NaN values in 'periodname'
# data = data.dropna(subset=['periodname'])

# # Function to parse dates with multiple formats
# def parse_dates(date_str):
#     for fmt in ('%B %Y', '%b-%y'):
#         try:
#             return pd.to_datetime(date_str, format=fmt)
#         except ValueError:
#             continue
#     return pd.NaT  # Return NaT if no format matches

# # Apply the function to the 'periodname' column
# data['periodname'] = data['periodname'].apply(parse_dates)

# # Drop rows with unprocessable date values
# data = data.dropna(subset=['periodname'])

# # Streamlit UI
# st.title('Time Series Analysis with Prophet')

# # Select data type (Service/Consumption/Both)
# data_type = st.selectbox('Select Data Type', ['Both', 'Consumption', 'Service'])

# # Select organization unit and common name for analysis
# org_unit = st.selectbox('Select Organization Unit', data['organisationunitname'].unique())
# common_name = st.selectbox('Select Common Name', data['common_name'].unique())

# # Filter data based on selections
# filtered_data = data[(data['organisationunitname'] == org_unit) & (data['common_name'] == common_name)]
# if data_type != 'Both':
#     filtered_data = filtered_data[filtered_data['Type'] == data_type]

# # Buttons for trend and forecasting
# if st.button('Show Trend'):
#     st.subheader('Trend')
#     fig = go.Figure()
    
#     if data_type in ['Both', 'Consumption']:
#         cons_data = filtered_data[filtered_data['Type'] == 'Consumption']
#         fig.add_trace(go.Scatter(x=cons_data['periodname'], y=cons_data['value'], mode='lines', name='Consumption', line=dict(color='blue')))
    
#     if data_type in ['Both', 'Service']:
#         serv_data = filtered_data[filtered_data['Type'] == 'Service']
#         fig.add_trace(go.Scatter(x=serv_data['periodname'], y=serv_data['value'], mode='lines', name='Service', line=dict(color='red')))
    
#     fig.update_layout(title='Trend', xaxis_title='Period', yaxis_title='Value', xaxis_showgrid=True, yaxis_showgrid=True)
#     st.plotly_chart(fig)

# if st.button('Show Forecast'):
#     st.subheader('Forecast')
    
#     # Prepare the data for Prophet
#     data_prophet = filtered_data[['periodname', 'value']].rename(columns={'periodname': 'ds', 'value': 'y'})
    
#     # Initialize and train the model
#     model = Prophet()
#     model.fit(data_prophet)
    
#     # Make a future dataframe for predictions
#     future = model.make_future_dataframe(periods=12, freq='M')  # Forecast for the next 12 months
#     forecast = model.predict(future)
    
#     # Filter forecast to show only future dates
#     forecast = forecast[forecast['ds'] >= '2024-07-01']
    
#     # Plot the forecast
#     fig = go.Figure()
    
#     if data_type in ['Both', 'Consumption']:
#         cons_data_prophet = data_prophet[data_prophet['y'].notnull()]
#         model_cons = Prophet()
#         model_cons.fit(cons_data_prophet)
#         future_cons = model_cons.make_future_dataframe(periods=12, freq='M')
#         forecast_cons = model_cons.predict(future_cons)
#         forecast_cons = forecast_cons[forecast_cons['ds'] >= '2024-07-01']
#         fig.add_trace(go.Scatter(x=forecast_cons['ds'], y=forecast_cons['yhat'], mode='lines', name='Consumption Forecast', line=dict(color='blue')))
    
#     if data_type in ['Both', 'Service']:
#         serv_data_prophet = data_prophet[data_prophet['y'].notnull()]
#         model_serv = Prophet()
#         model_serv.fit(serv_data_prophet)
#         future_serv = model_serv.make_future_dataframe(periods=12, freq='M')
#         forecast_serv = model_serv.predict(future_serv)
#         forecast_serv = forecast_serv[forecast_serv['ds'] >= '2024-07-01']
#         fig.add_trace(go.Scatter(x=forecast_serv['ds'], y=forecast_serv['yhat'], mode='lines', name='Service Forecast', line=dict(color='red')))
    
#     fig.update_layout(title='Forecast', xaxis_title='Period', yaxis_title='Value', xaxis_showgrid=True, yaxis_showgrid=True)
#     st.plotly_chart(fig)
    
#     # Display forecast data
#     st.write(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].reset_index(drop=True))
# Out:
# The kernel failed to start due to the missing module 'packaging'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
import pandas as pd

# Load the data
file_path = 'combined_product_data (1).csv'
data = pd.read_csv(file_path)

# Function to parse dates with multiple formats
def parse_dates(date_str):
    for fmt in ('%B %Y', '%b-%y'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    return pd.NaT  # Return NaT if no format matches

# Apply the function to the 'periodname' column
data['periodname'] = data['periodname'].apply(parse_dates)

# Drop rows with unprocessable date values
data = data.dropna(subset=['periodname'])

# Filter for a specific organization and product for demonstration
org_unit = 'Kakamega County'
common_name = 'COCs'
filtered_data = data[(data['organisationunitname'] == org_unit) & (data['common_name'] == common_name)]

# Prepare the data for time series forecasting
time_series_data = filtered_data[['periodname', 'value']].rename(columns={'periodname': 'ds', 'value': 'y'})
time_series_data = time_series_data.set_index('ds')

time_series_data.head()
# Out:
# Empty DataFrame
# Columns: [y]
# Index: []

# %%
pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/8.6 MB 1.1 MB/s eta 0:00:08
#    ---------------------------------------- 0.1/8.6 MB 871.5 kB/s eta 0:00:10
#     --------------------------------------- 0.1/8.6 MB 798.9 kB/s eta 0:00:11
#     --------------------------------------- 0.2/8.6 MB 803.1 kB/s eta 0:00:11
#     --------------------------------------- 0.2/8.6 MB 794.9 kB/s eta 0:00:11
#     --------------------------------------- 0.2/8.6 MB 731.4 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/8.6 MB 785.2 kB/s eta 0:00:11
#    - -------------------------------------- 0.3/8.6 MB 744.2 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/8.6 MB 729.6 kB/s eta 0:00:12
#    - -------------------------------------- 0.3/8.6 MB 744.3 kB/s eta 0:00:12
# ...

# %%
pip install plotly
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB 1.3 MB/s eta 0:00:13
#    ---------------------------------------- 0.1/16.4 MB 656.4 kB/s eta 0:00:25
#    ---------------------------------------- 0.1/16.4 MB 744.7 kB/s eta 0:00:22
#    ---------------------------------------- 0.2/16.4 MB 833.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.2/16.4 MB 841.6 kB/s eta 0:00:20
#     --------------------------------------- 0.3/16.4 MB 1.0 MB/s eta 0:00:17
#     --------------------------------------- 0.3/16.4 MB 981.5 kB/s eta 0:00:17
#    - -------------------------------------- 0.5/16.4 MB 1.2 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/16.4 MB 1.2 MB/s eta 0:00:14
#    - -------------------------------------- 0.5/16.4 MB 1.2 MB/s eta 0:00:14
# ...

# %%
pip install pandas numpy matplotlib statsmodels streamlit
# Out:
# ...
#
# ...

# %%
import numpy as np

# Monkey patch np.float_ to np.float64
np.float_ = np.float64

consumption_file_path = 'data (25).csv'
service_file_path = 'data (27).csv'
consumption_data =pd.read_csv(consumption_file_path)

service_data =pd.read_csv(service_file_path)
consumption_data.columns
# Out:
# Index(['periodid', 'periodname', 'periodcode', 'perioddescription',
#        'organisationunitid', 'organisationunitname', 'organisationunitcode',
#        'organisationunitdescription', 'MOH 747A_Cycle Beads Dispensed',
#        'MOH 747A_DMPA-IM Dispensed', 'MOH 747A_DMPA-SC Dispensed',
#        'MOH 747A_Emergency Contraceptive pills Dispensed',
#        'MOH 747A_Female Condoms Dispensed', 'MOH 747A_Hormonal IUCD Dispensed',
#        'MOH 747A_Implant (2-Rod) – LNG 75mg (5 years) Dispensed',
#        'MOH 747A_Implants (1-Rod) – ENG 68mg Dispensed',
#        'MOH 747A_Implants (2-Rod) - LNG 75mg (3 years) Dispensed',
#        'MOH 747A_Male Condoms Dispensed',
#        'MOH 747A_Non-Hormonal IUCD Dispensed', 'MOH 747A_Others Dispensed',
#        'MOH 747A_Progestin only pills Dispensed',
#        'MOH 747A_Combined Oral contraceptive Pills Dispensed'],
#       dtype='object')

# %%
service_data.columns
# Out:
# Index(['periodid', 'periodname', 'periodcode', 'perioddescription',
#        'organisationunitid', 'organisationunitname', 'organisationunitcode',
#        'organisationunitdescription',
#        'MOH 711 Rev 2020_Clients given cycle beads',
#        'MOH 711 Rev 2020_FP Injections DMPA- IM',
#        'MOH 711 Rev 2020_FP Injections DMPA- SC',
#        'MOH 711 Rev 2020_IUCD Insertion Hormonal',
#        'MOH 711 Rev 2020_IUCD Insertion Non Hormonal',
#        'MOH 711 Rev 2020_Implants insertion 1 Rod',
#        'MOH 711 Rev 2020_Implants insertion 2 Rod',
#        'MOH 711 Client receiving Male condoms',
#        'MOH 711 Clients receiving Female Condoms',
#        'MOH 711 Emergency contraceptive pill',
#        'MOH 711 Pills Combined oral contraceptive',
#        'MOH 711 Pills progestin only'],
#       dtype='object')

# %%
consumption_file_path = 'data (25).csv'
service_file_path = 'data (27).csv'
consumption_data = pd.read_csv(consumption_file_path)
service_data = pd.read_csv(service_file_path)

# Check the column names to ensure they match your data structure
print(consumption_data.columns)
print(service_data.columns)

# Assuming the data has columns for product descriptions and quantity
# Add a 'type' column to differentiate between consumption and service
consumption_data['type'] = 'consumption'
service_data['type'] = 'service'

# Concatenate the dataframes
combined_data = pd.concat([consumption_data, service_data], ignore_index=True)
# Out:
# Index(['periodid', 'periodname', 'periodcode', 'perioddescription',
#        'organisationunitid', 'organisationunitname', 'organisationunitcode',
#        'organisationunitdescription', 'MOH 747A_Cycle Beads Dispensed',
#        'MOH 747A_DMPA-IM Dispensed', 'MOH 747A_DMPA-SC Dispensed',
#        'MOH 747A_Emergency Contraceptive pills Dispensed',
#        'MOH 747A_Female Condoms Dispensed', 'MOH 747A_Hormonal IUCD Dispensed',
#        'MOH 747A_Implant (2-Rod) – LNG 75mg (5 years) Dispensed',
#        'MOH 747A_Implants (1-Rod) – ENG 68mg Dispensed',
#        'MOH 747A_Implants (2-Rod) - LNG 75mg (3 years) Dispensed',
#        'MOH 747A_Male Condoms Dispensed',
#        'MOH 747A_Non-Hormonal IUCD Dispensed', 'MOH 747A_Others Dispensed',
#        'MOH 747A_Progestin only pills Dispensed',
#        'MOH 747A_Combined Oral contraceptive Pills Dispensed'],
#       dtype='object')
# Index(['periodid', 'periodname', 'periodcode', 'perioddescription',
# ...

# %%
combined_data.columns
# Out:
# Index(['periodid', 'periodname', 'periodcode', 'perioddescription',
#        'organisationunitid', 'organisationunitname', 'organisationunitcode',
#        'organisationunitdescription', 'MOH 747A_Cycle Beads Dispensed',
#        'MOH 747A_DMPA-IM Dispensed', 'MOH 747A_DMPA-SC Dispensed',
#        'MOH 747A_Emergency Contraceptive pills Dispensed',
#        'MOH 747A_Female Condoms Dispensed', 'MOH 747A_Hormonal IUCD Dispensed',
#        'MOH 747A_Implant (2-Rod) – LNG 75mg (5 years) Dispensed',
#        'MOH 747A_Implants (1-Rod) – ENG 68mg Dispensed',
#        'MOH 747A_Implants (2-Rod) - LNG 75mg (3 years) Dispensed',
#        'MOH 747A_Male Condoms Dispensed',
#        'MOH 747A_Non-Hormonal IUCD Dispensed', 'MOH 747A_Others Dispensed',
#        'MOH 747A_Progestin only pills Dispensed',
#        'MOH 747A_Combined Oral contraceptive Pills Dispensed', 'type',
#        'MOH 711 Rev 2020_Clients given cycle beads',
#        'MOH 711 Rev 2020_FP Injections DMPA- IM',
# ...

# %%
import pandas as pd
import numpy as np

# Load the data
consumption_file_path = 'data (25).csv'
service_file_path = 'data (27).csv'
consumption_data = pd.read_csv(consumption_file_path)
service_data = pd.read_csv(service_file_path)

# Add a 'type' column to differentiate between consumption and service
consumption_data['type'] = 'consumption'
service_data['type'] = 'service'

# Concatenate the dataframes
combined_data = pd.concat([consumption_data, service_data], ignore_index=True)

# Melting the DataFrame to long format
long_data = combined_data.melt(id_vars=['periodid', 'organisationunitname', 'type'],
                               var_name='product_description', value_name='quantity')

# Check for null values in 'quantity' and fill with 0
long_data['quantity'].fillna(0, inplace=True)

# Mapping dictionary based on the given data
COLUMN_MAPPING = {
    'MOH 747A_Male Condoms': 'Male Condoms',
    'MOH 711 Client receiving Male condoms': 'Male Condoms',
    'MOH 747A_Female Condoms': 'Female Condoms',
    'MOH 711 Clients receiving Female Condoms': 'Female Condoms',
    'MOH 747A_Emergency Contraceptive pills': 'EC Pills',
    'MOH 711 Emergency contraceptive pill': 'EC Pills',
    'MOH 747A_Combined Oral contraceptive Pills': 'COCs',
    'MOH 711 Pills Combined oral contraceptive': 'COCs',
    'MOH 747A_Progestin only pills': 'POPs',
    'MOH 711 Pills progestin only': 'POPs',
    'MOH 747A_Cycle Beads': 'Cycle Beads',
    'MOH 711 Rev 2020_Clients given cycle beads': 'Cycle Beads',
    'MOH 747A_DMPA-IM': 'DMPA-IM',
    'MOH 711 Rev 2020_FP Injections DMPA- IM': 'DMPA-IM',
    'MOH 747A_DMPA-SC': 'DMPA-SC',
    'MOH 711 Rev 2020_FP Injections DMPA- SC': 'DMPA-SC',
    'MOH 747A_Implants (1-Rod) – ENG 68mg': 'Implanon',
    'MOH 711 Rev 2020_Implants insertion 1 Rod': 'Implanon',
    'MOH 711 Rev 2020_Implants insertion 2 Rod': '2 Rod',
    'MOH 747A_Hormonal IUCD': 'Hormonal IUCD',
    'MOH 711 Rev 2020_IUCD Insertion Hormonal': 'Hormonal IUCD',
    'MOH 747A_Non-Hormonal IUCD': 'Non-Hormonal IUCD',
    'MOH 711 Rev 2020_IUCD Insertion Non Hormonal': 'Non-Hormonal IUCD',
    'MOH 747A_Implants (2-Rod) - LNG 75mg (3 years)': 'Levoplant',
    'MOH 747A_Implant (2-Rod) – LNG 75mg (5 years)': 'Jadelle'
}

# Function to map common names
def map_common_name(description):
    for key, value in COLUMN_MAPPING.items():
        if key in description:
            return value
    return 'Unknown'

# Apply the mapping function
long_data['common_name'] = long_data['product_description'].apply(map_common_name)

# Remove rows with 'Unknown' common_name if necessary
long_data = long_data[long_data['common_name'] != 'Unknown']

# Aggregating the data by common_name, periodid, and organisationunitname
aggregated_data = long_data.groupby(['common_name', 'periodid', 'organisationunitname']).agg({'quantity': 'sum'}).reset_index()

# Fill missing values with 0
aggregated_data['quantity'].fillna(0, inplace=True)

# Save or use the cleaned and aggregated data
# Example: aggregated_data.to_csv('cleaned_data_for_forecasting.csv', index=False)

# Display the processed data
print(aggregated_data.head())
# Out:
# C:\Users\Grace\AppData\Local\Temp\ipykernel_12556\1482822706.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   long_data['quantity'].fillna(0, inplace=True)
#   common_name  periodid    organisationunitname quantity
# 0       2 Rod    202001          Baringo County        0
# 1       2 Rod    202001            Bomet County        0
# 2       2 Rod    202001          Bungoma County        0
# 3       2 Rod    202001            Busia County        0
# 4       2 Rod    202001  Elgeyo Marakwet County        0
# ...

# %%
data["periodid"].isna().sum()
# Out:
# np.int64(54)

# %%
# Ensure the necessary packages are installed

# ARIMA and SARIMA implementation
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np

# Load the data
file_path = 'combined_product_data (1).csv'
data = pd.read_csv(file_path)

# Function to parse dates with multiple formats
def parse_dates(date_str):
    for fmt in ('%B %Y', '%b-%y'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            continue
    return pd.NaT  # Return NaT if no format matches

# Apply the function to the 'periodname' column
data['periodname'] = data['periodname'].apply(parse_dates)

# Drop rows with unprocessable date values
data = data.dropna(subset=['periodname'])

# Filter for a specific organization and product for demonstration
org_unit = 'Kakamega County'
common_name = 'COCs'
filtered_data = data[(data['organisationunitname'] == org_unit) & (data['common_name'] == common_name)]

# Prepare the data for time series forecasting
time_series_data = filtered_data[['periodname', 'value']].rename(columns={'periodname': 'ds', 'value': 'y'})
time_series_data = time_series_data.set_index('ds')

# Split data into training and test sets
train = time_series_data.iloc[:-12]  # Training on all data except the last 12 months
test = time_series_data.iloc[-12:]   # Testing on the last 12 months

# ARIMA model
model_arima = ARIMA(train, order=(5,1,0))
model_arima_fit = model_arima.fit()

# Forecast
forecast_arima = model_arima_fit.forecast(steps=12)
rmse_arima = np.sqrt(mean_squared_error(test, forecast_arima))
print(f'ARIMA RMSE: {rmse_arima}')

# SARIMA model
model_sarima = SARIMAX(train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_sarima_fit = model_sarima.fit(disp=False)

# Forecast
forecast_sarima = model_sarima_fit.forecast(steps=12)
rmse_sarima = np.sqrt(mean_squared_error(test, forecast_sarima))
print(f'SARIMA RMSE: {rmse_sarima}')
# Out:
# c:\Users\Grace\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Grace\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Grace\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
import numpy as np
